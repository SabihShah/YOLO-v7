# %%
# Download YOLOv7 repository and install requirements
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# %pip install -r requirements.txt

# %%
import os

train_img_path = 'images/train/'
val_img_path = 'images/val/'

# %% [markdown]
# copy the images and labels to the directories inside the yolov7 directory

# %%
with open('train.txt', 'a+') as f:
    img_list = os.listdir(train_img_path)

    for img in img_list:
        f.write(os.path.join(train_img_path, img+'/n'))

    print("DONE")
# Out:
# DONE

# %%
with open('val.txt', 'a+') as f:
    img_list = os.listdir(val_img_path)

    for img in img_list:
        f.write(os.path.join(val_img_path, img+'/n'))

    print("DONE")
# Out:
# DONE

# %%
import matplotlib.pyplot as plt

img = plt.imread(train_img_path + '1_jpg.rf.7a3da88eac18281cee4bcc4ee5aab952.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 899.5, 505.5, -0.5)

# %% [markdown]
# copy the data.yaml file in /yolov7/data/data.yaml

# %% [markdown]
# ### Download yolov7 model from model zoo provided on their official github page

# %%
import requests

url = "https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-tiny.pt"
output_file = "yolov7-tiny.pt"

response = requests.get(url)
with open(output_file, 'wb') as f:
    f.write(response.content)

print("File downloaded successfully.")
# Out:
# File downloaded successfully.

# %% [markdown]
# Crete a copy of yolov7-tiny in cfg to make a custom configuration file

# %%
os.getcwd()
# Out:
# 'd:\\Deep Learning Models\\data_yolov7'

# %% [markdown]
# ## Model Training

# %%
# !python "data_yolov7\yolov7\train.py" --batch 16 --cfg "data_yolov7\yolov7\cfg\training\custom_yolov7-tiny.yaml" --epochs 100 --data "data_yolov7\yolov7\data\data.yaml" --weights "data_yolov7\yolov7\yolov7-tiny.pt"
